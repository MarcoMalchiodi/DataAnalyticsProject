# %%
import pandas as pd

# %%
df = pd.read_csv("SOYBEAN PRODUCTION $.csv")
df.head()
# Out:
#   Program  Year Period  Week Ending Geo Level     State  State ANSI  \
# 0  SURVEY  2023   YEAR          NaN     STATE  ILLINOIS          17
# 1  SURVEY  2022   YEAR          NaN     STATE  ILLINOIS          17
# 2  SURVEY  2021   YEAR          NaN     STATE  ILLINOIS          17
# 3  SURVEY  2020   YEAR          NaN     STATE  ILLINOIS          17
# 4  SURVEY  2019   YEAR          NaN     STATE  ILLINOIS          17
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
# 1          NaN               NaN     NaN  ...       NaN     NaN
# 2          NaN               NaN     NaN  ...       NaN     NaN
# 3          NaN               NaN     NaN  ...       NaN     NaN
# 4          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed  Commodity                             Data Item  \
# 0               0        NaN   SOYBEANS  SOYBEANS - PRODUCTION, MEASURED IN $
# ...

# %%
df = df[['Year','State','Commodity','Value']]

# %%
df.to_excel("SOYBEAN PRODUCTION $.xlsx")
